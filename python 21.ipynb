# %%
#line graph
import matplotlib.pyplot as plt
days=list(range(1,31))
temperatures=[68,70,72,75,77,80,82,83,81,78,75,72,71,70,72,74,77,79,80,82,84,86,88,87,85,82,80,77,75,73]
plt.plot(days,temperatures,marker='o')
plt.xlabel("day of the month")
plt.ylabel("temperature over a month")
plt.show()

# %%
import matplotlib.pyplot as plt
categories=['rent','groceries','utilities','entertainment','transportation']
expenses=[1200,400,200,150,250]
plt.bar(categories,expenses)
plt.xlabel('categories')
plt.ylabel('expenses')
plt.show()

# %%
import matplotlib.pyplot as plt

days=list(range(1,78))
stock_prices=[100,105,110,115,112,120,118,125,128,130,132,135,138,140,142,144,145,148,150,155,160,158,162,165,170,172,175,178,180,182,185,188,190,192,195,198,200,198,195,193,190,188,185,182,180,178,175,172,170,168,165,162,160,158,155,152,150,148,145,143,140,138,135,132,130,128,125,123,120,118,115,112,110,108,105,103,100]
plt.plot(days,stock_prices, marker='o')
plt.xlabel("day of the month")
plt.ylabel("stock prices")
plt.show()

# %%
import matplotlib.pyplot as plt
genres=['rent','groceries','utilities','entertainment','transportation']
books_sold=[1200,400,200,150,250]
plt.bar(categories,expenses)
plt.xlabel('genres')
plt.ylabel('books_sold')
plt.show()

# %%
#pie chart

# %%
import matplotlib.pyplot as plt
manufacturers=['samsung','apple','huawei','xiaomi','others']
market_share=[30,25,18,12,15]
plt.pie(market_share, labels=manufacturers)
plt.title('smartphone market share')
plt.show()

# %%
income_soures=['salary','freelance','investments','rental','other']
monthly_income=[5000,1500,1000,600,400]
plt.pie(monthly_income,labels=income_soures)

plt.show()

# %%
segments=['product A','product B','services','licensing']
revenue_percentages=[45,25,15,15]
plt.pie(revenue_percentages , labels=segments)
plt.show()

# %%
#scatter plot

# %%
study_hours=[2,3,1,5,7,4,4,10,20,60,3,7,9,15,6]
exam_scores=[65,75,60,80,70,85,70,90,88,92,100,50,60,100,90]
plt.scatter(study_hours,exam_scores,label='Student Data')
plt.xlabel('study hours')
plt.ylabel('exam scores')
plt.title('study hours vs exam scores')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
square_footage=np.array([1200,1400,1600,1800,2000,2200,2400,2600,2800,3000])
selling_prices=np.array([250,290,315,380,410,450,500,525,570,610])
plt.scatter(square_footage,selling_prices)
plt.xlabel=('square_footage')
plt.ylabel=('selling_prices')
plt.title('square_footage vs selling_prices')
plt.show()

# %%
categories=['rent','food','transport','entertainment','savings']
values=[35, 25, 15, 10,15]
plt.pie(values, labels=categories)
plt.show()
